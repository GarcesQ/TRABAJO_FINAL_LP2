# %% [markdown]
# ## 1. Análisis de Productos

# %% [markdown]
# ### Productos por categoría:

# %%
import requests
import pandas as pd

def search_products_by_category(category, page_size=20):
    url = f'https://world.openfoodfacts.org/category/{category}.json?page_size={page_size}'
    response = requests.get(url)
    
    if response.status_code == 200:
        products = response.json().get('products', [])
        return products
    else:
        return []

def print_products(products):
    for idx, product in enumerate(products):
        print(f"Producto {idx + 1}:")
        print("ID:", product.get('id', 'N/A'))
        print("Nombre:", product.get('product_name', 'N/A'))
        print()

# Ejemplo de uso:
categories = ['chocolates', 'cereals', 'cheeses']  # 3 categorías diferentes
for category in categories:
    print(f"Buscando productos en la categoría '{category}':")
    products = search_products_by_category(category)
    print_products(products)
# Out:
# Buscando productos en la categoría 'chocolates':
# Producto 1:
# ID: 3474341105842
# Nombre: Chocolat noir 65% de cacao
#
# Producto 2:
# ID: 3046920022651
# Nombre: 70% Cacao noir intense
#
# Producto 3:
# ID: 3046920029759
# Nombre: Noir Excellence 90%
#
# Producto 4:
# ID: 3046920022606
# Nombre: Excellence 85% Cacao Chocolat Noir Puissant
#
# Producto 5:
# ID: 20995553
# Nombre: Edelbitter mild 85%
#
# Producto 6:
# ID: 20022464
# Nombre: Extra dark chocolate 74% cacao
#
# Producto 7:
# ID: 3045140105502
# Nombre: Milka Lait Alpin
#
# Producto 8:
# ID: 3046920028004
# Nombre: Excellence 70% Cocoa Intense Dark
#
# Producto 9:
# ID: 7613035040823
# Nombre: Nestlé Dessert
#
# Producto 10:
# ID: 3046920028363
# Nombre: 85% Cocoa Robust Dark Chocolate Bar
#
# Producto 11:
# ID: 3046920029780
# Nombre: Doux 70% noir subtil
#
# Producto 12:
# ID: 20095291
# Nombre: Ecuador Edelbitter 70%
#
# Producto 13:
# ID: 40896243
# Nombre: Bio Chocolat Noir Cacao 70%
#
# Producto 14:
# ID: 7622210995087
# Nombre: Noir - Noisettes Entières
#
# Producto 15:
# ID: 3046920028721
# Nombre: Excellence 99% Cacao Noir Absolute
#
# Producto 16:
# ID: 3664346305860
# Nombre: Noir Extra
#
# Producto 17:
# ID: 3046920010047
# Nombre: Chocolat noir extra-fin, traditionnel.
#
# Producto 18:
# ID: 3046920027885
# Nombre: Chocolat noir 47% et pointe de fleur de sel
#
# Producto 19:
# ID: 20713713
# Nombre: Bio Chocolat Noir Equateur 85% cacao
#
# Producto 20:
# ID: 20022471
# Nombre: Čokoláda
#
# Buscando productos en la categoría 'cereals':
# Producto 1:
# ID: 3168930010265
# Nombre: Cruesli Mélange De Noix
#
# Producto 2:
# ID: 7613034626844
# Nombre: Céréales Chocapic
#
# Producto 3:
# ID: 7394376616228
# Nombre: Oat Drink Barista Edition
#
# Producto 4:
# ID: 20003166
# Nombre: Haferflocken Extra zart
#
# Producto 5:
# ID: 3229820019307
# Nombre: Flocons d'avoine céréale complète
#
# Producto 6:
# ID: 5411188124689
# Nombre: Ohne Zucker Hafer
#
# Producto 7:
# ID: 3229820782560
# Nombre: Muesli Superfruits
#
# Producto 8:
# ID: 5010029000016
# Nombre: Weetabix
#
# Producto 9:
# ID: 3760049798609
# Nombre: Pain de mie grandes tranches Seigle & Graines 500g
#
# Producto 10:
# ID: 5010029000023
# Nombre: Weetabix produit à base de blé complet 100%
#
# Producto 11:
# ID: 3168930009078
# Nombre: Flocons d'avoine complète
#
# Producto 12:
# ID: 3229820129488
# Nombre: Muesli Raisin, Figue, Abricot
#
# Producto 13:
# ID: 7613034947611
# Nombre: NESTLE CHOCAPIC Céréales 750g
#
# Producto 14:
# ID: 4008713756661
# Nombre: Copos de avena
#
# Producto 15:
# ID: 8712100338694
# Nombre:
#
# Producto 16:
# ID: 3229820160672
# Nombre: Croustillant Chocolat
#
# Producto 17:
# ID: 5010029000801
# Nombre: Weetabix
#
# Producto 18:
# ID: 3159470000120
# Nombre: Corn Flakes
#
# Producto 19:
# ID: 5010477348678
# Nombre: Special Muesli 30% fruits & noix
#
# Producto 20:
# ID: 8076800195057
# Nombre: Spaghetti n°5
#
# Buscando productos en la categoría 'cheeses':
# Producto 1:
# ID: 4099200191041
# Nombre: Ziegenfrischkäse Natur
#
# Producto 2:
# ID: 3480341000674
# Nombre: Carré frais 0%
#
# Producto 3:
# ID: 3161711001971
# Nombre: Caprice des dieux
#
# Producto 4:
# ID: 3412290070101
# Nombre: Paysan Breton - Le Fromage Fouetté Madame Loïk - Nature au Sel de Guérande
#
# Producto 5:
# ID: 3023260030928
# Nombre: Salakis 100% Brebis
#
# Producto 6:
# ID: 3480341000636
# Nombre: Carré frais
#
# Producto 7:
# ID: 3272770098090
# Nombre: St Môret
#
# Producto 8:
# ID: 3523230028431
# Nombre: La bûche Sainte-Maure (Poitou-Charentes
#
# Producto 9:
# ID: 3228021170039
# Nombre: PRESIDENT CAMEMBERT 250g
#
# Producto 10:
# ID: 3176582033563
# Nombre: Coulommiers Doux et Crémeux
#
# Producto 11:
# ID: 3228021170022
# Nombre: President emmental coeur de meule 250g
#
# Producto 12:
# ID: 3272770097642
# Nombre: Le Goût Primeur format familial
#
# Producto 13:
# ID: 3161711000622
# Nombre: Caprice des dieux
#
# Producto 14:
# ID: 3412290070071
# Nombre: Paysan Breton - Le Fromage Fouetté Madame Loïk - Nature au Sel de Guérande
#
# Producto 15:
# ID: 3073781131888
# Nombre: Kiri-Käse
#
# Producto 16:
# ID: 3033491454080
# Nombre: SKYR
#
# Producto 17:
# ID: 3073781192186
# Nombre: La vache qui rit
#
# Producto 18:
# ID: 3073781131925
# Nombre: Kiri® Crème 12 portions
#
# Producto 19:
# ID: 8721800402055
# Nombre: Leerdammer original 8 tranches 200g
#
# Producto 20:
# ID: 3272770094412
# Nombre: L'original tartare ail & fines herbes

# %% [markdown]
# ### Información sobre cada producto:

# %%
import requests
import pandas as pd

def search_products_by_category(category, page_size=20):
    url = f'https://world.openfoodfacts.org/category/{category}.json?page_size={page_size}'
    response = requests.get(url)
    
    if response.status_code == 200:
        products = response.json().get('products', [])
        return products
    else:
        return []

def get_product_info(product_id):
    url = f'https://world.openfoodfacts.org/api/v0/product/{product_id}.json'
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json().get('product', {})
    else:
        return None

def collect_product_details(products):
    data = []
    
    for product in products:
        product_id = product.get('id', 'N/A')
        product_name = product.get('product_name', 'N/A')
        
        detailed_product = get_product_info(product_id)
        
        if detailed_product:
            product_details = {
                'Producto': product_name,
                'Categoría': category,
                'Energía (kcal)': detailed_product.get('nutriments', {}).get('energy-kcal_100g', 'N/A'),
                'Grasas (g)': detailed_product.get('nutriments', {}).get('fat_100g', 'N/A'),
                'Proteínas (g)': detailed_product.get('nutriments', {}).get('proteins_100g', 'N/A'),
                'Hidratos de Carbono (g)': detailed_product.get('nutriments', {}).get('carbohydrates_100g', 'N/A')
            }
            data.append(product_details)
        else:
            print(f"No se encontró información detallada para el producto {product_id}.")
    
    return data

# Categorías a buscar
categories = ['chocolates', 'cereals', 'cheeses']

# Recolectar detalles de productos y construir el dataframe
all_product_details = []
for category in categories:
    products = search_products_by_category(category)
    category_details = collect_product_details(products)
    all_product_details.extend(category_details)

# Crear un DataFrame con los detalles recolectados
df_products = pd.DataFrame(all_product_details)

# Mostrar el DataFrame
print("Tabla de Información Nutricional de Productos:")
print(df_products)

# Guardar el DataFrame en un archivo CSV
csv_filename = 'productos_nutricion.csv'
df_products.to_csv(csv_filename, index=False)
print(f"\nLos datos han sido guardados en '{csv_filename}'.")
# Out:
# Tabla de Información Nutricional de Productos:
#                                              Producto   Categoría  \
# 0                          Chocolat noir 65% de cacao  chocolates
# 1                              70% Cacao noir intense  chocolates
# 2                                 Noir Excellence 90%  chocolates
# 3         Excellence 85% Cacao Chocolat Noir Puissant  chocolates
# 4                                 Edelbitter mild 85%  chocolates
# 5                      Extra dark chocolate 74% cacao  chocolates
# 6                                    Milka Lait Alpin  chocolates
# 7                   Excellence 70% Cocoa Intense Dark  chocolates
# 8                                      Nestlé Dessert  chocolates
# 9                 85% Cocoa Robust Dark Chocolate Bar  chocolates
# 10                               Doux 70% noir subtil  chocolates
# 11                             Ecuador Edelbitter 70%  chocolates
# 12                        Bio Chocolat Noir Cacao 70%  chocolates
# 13                          Noir - Noisettes Entières  chocolates
# 14                 Excellence 99% Cacao Noir Absolute  chocolates
# 15                                         Noir Extra  chocolates
# 16             Chocolat noir extra-fin, traditionnel.  chocolates
# 17        Chocolat noir 47% et pointe de fleur de sel  chocolates
# 18               Bio Chocolat Noir Equateur 85% cacao  chocolates
# 19                                           Čokoláda  chocolates
# 20                            Cruesli Mélange De Noix     cereals
# 21                                  Céréales Chocapic     cereals
# 22                          Oat Drink Barista Edition     cereals
# 23                            Haferflocken Extra zart     cereals
# 24                  Flocons d'avoine céréale complète     cereals
# 25                                  Ohne Zucker Hafer     cereals
# 26                                 Muesli Superfruits     cereals
# 27                                           Weetabix     cereals
# 28  Pain de mie grandes tranches Seigle & Graines ...     cereals
# 29        Weetabix produit à base de blé complet 100%     cereals
# 30                          Flocons d'avoine complète     cereals
# 31                      Muesli Raisin, Figue, Abricot     cereals
# 32                      NESTLE CHOCAPIC Céréales 750g     cereals
# 33                                     Copos de avena     cereals
# 34                                                        cereals
# 35                              Croustillant Chocolat     cereals
# 36                                           Weetabix     cereals
# 37                                        Corn Flakes     cereals
# 38                   Special Muesli 30% fruits & noix     cereals
# 39                                      Spaghetti n°5     cereals
# 40                             Ziegenfrischkäse Natur     cheeses
# 41                                     Carré frais 0%     cheeses
# 42                                  Caprice des dieux     cheeses
# 43  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 44                                Salakis 100% Brebis     cheeses
# 45                                        Carré frais     cheeses
# 46                                           St Môret     cheeses
# 47            La bûche Sainte-Maure (Poitou-Charentes     cheeses
# 48                           PRESIDENT CAMEMBERT 250g     cheeses
# 49                        Coulommiers Doux et Crémeux     cheeses
# 50             President emmental coeur de meule 250g     cheeses
# 51                    Le Goût Primeur format familial     cheeses
# 52                                  Caprice des dieux     cheeses
# 53  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 54                                          Kiri-Käse     cheeses
# 55                                               SKYR     cheeses
# 56                                   La vache qui rit     cheeses
# 57                            Kiri® Crème 12 portions     cheeses
# 58                Leerdammer original 8 tranches 200g     cheeses
# 59              L'original tartare ail & fines herbes     cheeses
#
#     Energía (kcal)  Grasas (g)  Proteínas (g)  Hidratos de Carbono (g)
# 0              559        41.0            6.8                     35.0
# 1              566        41.0            9.5                     34.0
# 2              592        55.0           10.0                     14.0
# 3              584        46.0           12.5                     22.0
# 4              579        46.8           10.8                     21.4
# 5              570        42.0           10.0                     32.0
# 6              539        31.0            6.5                     57.0
# 7              566        41.0            9.5                     34.0
# 8              548        34.1            6.0                     50.7
# 9              584        46.0           12.5                     22.0
# 10             610        48.0            6.9                     33.0
# 11             565        41.5            8.4                     33.8
# 12             572        41.6            8.5                     35.3
# 13             569        39.0            7.3                     43.0
# 14             590        51.0           15.0                      8.0
# 15             508        28.0            4.9                     55.0
# 16             576        46.0           10.0                     24.0
# 17             537        32.0            5.7                     52.0
# 18             639        55.3            9.0                     20.6
# 19             544        35.0            4.8                     48.0
# 20             462        19.0            8.5                     57.0
# 21             388         4.8            8.8                     73.6
# 22              61         3.0            1.1                      7.1
# 23             372         7.0           13.5                     58.7
# 24             362         7.1           11.0                     58.0
# 25              40         1.5            0.2                      5.8
# 26             357         6.0           11.0                     60.0
# 27             362         2.0           12.0                     69.0
# 28             297         9.6           12.0                     37.0
# 29             362         2.0           12.0                     69.0
# 30             375         8.0           11.0                     60.0
# 31             352         5.8           11.0                     59.0
# 32             388         4.8            8.8                     73.6
# 33             375         7.0           14.0                     59.0
# 34             355         0.5            0.5                     86.0
# 35             437        15.0            9.7                     61.0
# 36             362         2.0           12.0                     69.0
# 37             378         0.9            7.0                     84.0
# 38             362         7.2           10.2                     59.6
# 39             359         2.0           13.0                     71.0
# 40             177        13.0           11.0                      4.0
# 41              78         0.2           17.5                      1.5
# 42             333        30.0           15.0                      0.8
# 43             252        24.0            5.9                      3.0
# 44             272        22.8           15.7                      0.8
# 45             193        15.0           12.0                      2.5
# 46             205        17.8            8.3                      3.0
# 47             291        23.0           20.0                      1.0
# 48             269        21.0           20.0                      0.0
# 49             283        23.0           18.0                      1.0
# 50             369        29.0           27.0                      0.5
# 51             205        17.8            8.3                      3.0
# 52             333        30.0           15.3                      0.8
# 53             252        24.0            5.9                      3.0
# 54             305        29.0            9.0                      2.0
# 55              57         0.2           10.0                      3.9
# 56             228        17.5           11.5                      6.0
# 57             305        29.0            9.0                      2.0
# 58             352        27.5           26.0                      0.1
# 59             348        34.5            7.0                      2.3
#
# Los datos han sido guardados en 'productos_nutricion.csv'.

# %% [markdown]
# ## 2. Segmentación de Mercado

# %% [markdown]
# ### Recopilar y Limpiar los Datos:
# Vamos a agregar algunos ingredientes y su categoría protéica y dietética.

# %%
import requests
import pandas as pd

def search_products_by_category(category, page_size=20):
    url = f'https://world.openfoodfacts.org/category/{category}.json?page_size={page_size}'
    response = requests.get(url)
    
    if response.status_code == 200:
        products = response.json().get('products', [])
        return products
    else:
        return []

def get_product_info(product_id):
    url = f'https://world.openfoodfacts.org/api/v0/product/{product_id}.json'
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json().get('product', {})
    else:
        return None

def collect_product_details(products, category):
    data = []
    
    for product in products:
        product_id = product.get('id', 'N/A')
        product_name = product.get('product_name', 'N/A')
        
        detailed_product = get_product_info(product_id)
        
        if detailed_product:
            product_details = {
                'Producto': product_name,
                'Categoría': category,
                'Ingredientes': detailed_product.get('ingredients_text', 'N/A'),
                'Energía (kcal)': detailed_product.get('nutriments', {}).get('energy-kcal_100g', 'N/A'),
                'Grasas (g)': detailed_product.get('nutriments', {}).get('fat_100g', 'N/A'),
                'Proteínas (g)': detailed_product.get('nutriments', {}).get('proteins_100g', 'N/A'),
                'Hidratos de Carbono (g)': detailed_product.get('nutriments', {}).get('carbohydrates_100g', 'N/A'),
                'Azúcares (g)': detailed_product.get('nutriments', {}).get('sugars_100g', 'N/A')
            }
            data.append(product_details)
        else:
            print(f"No se encontró información detallada para el producto {product_id}.")
    
    return data

# Categorías a buscar
categories = ['chocolates', 'cereals', 'cheeses']

# Recolectar detalles de productos y construir el dataframe
all_product_details = []
for category in categories:
    products = search_products_by_category(category)
    category_details = collect_product_details(products, category)
    all_product_details.extend(category_details)

# Crear un DataFrame con los detalles recolectados
df_products = pd.DataFrame(all_product_details)

# Mostrar el DataFrame
print("Tabla de Información Nutricional de Productos:")
print(df_products)
# Out:
# Tabla de Información Nutricional de Productos:
#                                              Producto   Categoría  \
# 0                          Chocolat noir 65% de cacao  chocolates
# 1                              70% Cacao noir intense  chocolates
# 2                                 Noir Excellence 90%  chocolates
# 3         Excellence 85% Cacao Chocolat Noir Puissant  chocolates
# 4                                 Edelbitter mild 85%  chocolates
# 5                      Extra dark chocolate 74% cacao  chocolates
# 6                                    Milka Lait Alpin  chocolates
# 7                   Excellence 70% Cocoa Intense Dark  chocolates
# 8                                      Nestlé Dessert  chocolates
# 9                 85% Cocoa Robust Dark Chocolate Bar  chocolates
# 10                               Doux 70% noir subtil  chocolates
# 11                             Ecuador Edelbitter 70%  chocolates
# 12                        Bio Chocolat Noir Cacao 70%  chocolates
# 13                          Noir - Noisettes Entières  chocolates
# 14                 Excellence 99% Cacao Noir Absolute  chocolates
# 15                                         Noir Extra  chocolates
# 16             Chocolat noir extra-fin, traditionnel.  chocolates
# 17        Chocolat noir 47% et pointe de fleur de sel  chocolates
# 18               Bio Chocolat Noir Equateur 85% cacao  chocolates
# 19                                           Čokoláda  chocolates
# 20                            Cruesli Mélange De Noix     cereals
# 21                                  Céréales Chocapic     cereals
# 22                          Oat Drink Barista Edition     cereals
# 23                            Haferflocken Extra zart     cereals
# 24                  Flocons d'avoine céréale complète     cereals
# 25                                  Ohne Zucker Hafer     cereals
# 26                                 Muesli Superfruits     cereals
# 27                                           Weetabix     cereals
# 28  Pain de mie grandes tranches Seigle & Graines ...     cereals
# 29        Weetabix produit à base de blé complet 100%     cereals
# 30                          Flocons d'avoine complète     cereals
# 31                      Muesli Raisin, Figue, Abricot     cereals
# 32                      NESTLE CHOCAPIC Céréales 750g     cereals
# 33                                     Copos de avena     cereals
# 34                                                        cereals
# 35                              Croustillant Chocolat     cereals
# 36                                           Weetabix     cereals
# 37                                        Corn Flakes     cereals
# 38                   Special Muesli 30% fruits & noix     cereals
# 39                                      Spaghetti n°5     cereals
# 40                             Ziegenfrischkäse Natur     cheeses
# 41                                     Carré frais 0%     cheeses
# 42                                  Caprice des dieux     cheeses
# 43  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 44                                Salakis 100% Brebis     cheeses
# 45                                        Carré frais     cheeses
# 46                                           St Môret     cheeses
# 47            La bûche Sainte-Maure (Poitou-Charentes     cheeses
# 48                           PRESIDENT CAMEMBERT 250g     cheeses
# 49                        Coulommiers Doux et Crémeux     cheeses
# 50             President emmental coeur de meule 250g     cheeses
# 51                    Le Goût Primeur format familial     cheeses
# 52                                  Caprice des dieux     cheeses
# 53  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 54                                          Kiri-Käse     cheeses
# 55                                               SKYR     cheeses
# 56                                   La vache qui rit     cheeses
# 57                            Kiri® Crème 12 portions     cheeses
# 58                Leerdammer original 8 tranches 200g     cheeses
# 59              L'original tartare ail & fines herbes     cheeses
#
#                                          Ingredientes  Energía (kcal)  \
# 0                                                                 559
# 1          cocoa paste, sugar, cocoa butter, vanilla,             566
# 2   cocoa mass, cocoa butter, low-fat cocoa, sugar...             592
# 3   Pâte de cacao, cacao maigre, beurre de cacao, ...             584
# 4   Kakaomasse, fettarmes Kakaopulver, Kakaobutter...             579
# 5   cocoa mass, sugar, cocoa butter, fat reduced c...             570
# 6   Sucre, beurre de cacao, pâte de cacao, LAIT éc...             539
# 7           Cocoa mass, sugar, cocoa butter, vanilla.             566
# 8   sugar, cocoa paste, cocoa butter, emulsifier s...             548
# 9   cocoa mass, fat-reduced cocoa, cocoa butter, d...             584
# 10  cocoa mass, sugar, cocoa butter, emulsifier (s...             610
# 11  Kakaomasse, Zucker, Kakaobutter, Emulgator: Le...             565
# 12  Pâte de cacao¹, sucre de canne¹, beurre de cac...             572
# 13  Sucre, pâte de cacao, NOISETTES (24%), beurre ...             569
# 14  Cocoa solids 99%, Cocoa paste, fat-reduced coc...             590
# 15  sugar, cocoa paste, cocoa butter, lean cocoa p...             508
# 16  Pâte de cacao, beurre de cacao, sucre, cacao m...             576
# 17  sugar, cocoa paste, cocoa butter, concentrated...             537
# 18  Pâte de cacao* Équateur, beurre de cacao*, suc...             639
# 19  sugar, cocoa paste, cocoa butter, emulsifier: ...             544
# 20  _avoine_ complète (32%), _blé_ complet (18%), ...             462
# 21  Blé complet 35,0%, chocolat en poudre 22,5% (s...             388
# 22  Water, _OATS_ 10%, rapeseed oil, acidity regul...              61
# 23                             soft whole-oat flakes,             372
# 24  Flocons d'_avoine_ complète issue de l'agricul...             362
# 25  Haferbasis (Wasser,  Hafer (8,7%)), Zichorienw...              40
# 26  Flocons d'_avoine_ complète 60 %, raisins secs...             357
# 27  wholegrain wheat (95%), malted barley extract,...             362
# 28  Farine de BLÉ* 41 % , eau, graines de lin brun...             297
# 29  _Blé_ complet (95%), extrait d'_orge_ maltée, ...             362
# 30                             100% Flocons d'avoine.             375
# 31  Flocons d'avoine* complète, Flocons de blé* co...             352
# 32  BLE complet 35,0%, chocolat en poudre 22,5% (s...             388
# 33                                Avena integral 100%             375
# 34                                        corn starch             355
# 35  Flocons d'avoine complète, Flocons de blé comp...             437
# 36  Wholegrain _Wheat_ (95%), Malted _Barley_ Extr...             362
# 37  corn, sugar, aroma of malt of barley, salt, vi...             378
# 38  Céréales complètes flocons d'avoine, flocons d...             362
# 39  Semoule de BLÉ dur, eau. Peut contenir des tra...             359
# 40                             Ziegenfrischkäse, Salz             177
# 41               Lait écrémé, sel, ferments lactiques              78
# 42  pasteurized cow's milk and cream from france, ...             333
# 43              _Fromage_ frais, sel de Guérande 1,1%             252
# 44                                       sheep cheese             272
# 45          whole milk, cream, salt, lactic ferments,             193
# 46  _lait_ et _crème_ pasteurisés (Origine: France...             205
# 47  goat's milk (origin france), salt, ferments, c...             291
# 48  LAIT (origine France), ferments lactiques et d...             269
# 49         cow's milk, salt, ferments (contain milk),             283
# 50          LAIT pasteurisé de vache , sel, ferments.             369
# 51  Lait et crème pasteurisés (Origine : France), ...             205
# 52  lait de vache pasteurisé de France, sel, ferme...             333
# 53                Fromage frais, sel de Guérande 1,1%             252
# 54  pasteurized fresh milk 53% (origin: france), c...             305
# 55  Lait écrémé, ferments lactiques (lait). Lait: ...              57
# 56  LAIT écrémé réhydraté (origine : France), FROM...             228
# 57  LAIT frais pasteurisé 53% (origine : France), ...             305
# 58  LAIT pasteurisé, sel, ferments LACTIQUES, enzy...             352
# 59  Lait et crème pasteurisés (origine: France), a...             348
#
#     Grasas (g)  Proteínas (g)  Hidratos de Carbono (g)  Azúcares (g)
# 0         41.0            6.8                     35.0          32.0
# 1         41.0            9.5                     34.0          30.0
# 2         55.0           10.0                     14.0           7.0
# 3         46.0           12.5                     22.0          15.0
# 4         46.8           10.8                     21.4          12.9
# 5         42.0           10.0                     32.0          26.0
# 6         31.0            6.5                     57.0          55.0
# 7         41.0            9.5                     34.0          30.0
# 8         34.1            6.0                     50.7          46.4
# 9         46.0           12.5                     22.0          15.0
# 10        48.0            6.9                     33.0          29.0
# 11        41.5            8.4                     33.8          27.2
# 12        41.6            8.5                     35.3          28.0
# 13        39.0            7.3                     43.0          40.0
# 14        51.0           15.0                      8.0           1.0
# 15        28.0            4.9                     55.0          52.0
# 16        46.0           10.0                     24.0          17.0
# 17        32.0            5.7                     52.0          47.0
# 18        55.3            9.0                     20.6          14.0
# 19        35.0            4.8                     48.0          45.6
# 20        19.0            8.5                     57.0          12.0
# 21         4.8            8.8                     73.6          22.4
# 22         3.0            1.1                      7.1           4.0
# 23         7.0           13.5                     58.7           0.7
# 24         7.1           11.0                     58.0           1.7
# 25         1.5            0.2                      5.8           0.0
# 26         6.0           11.0                     60.0          14.0
# 27         2.0           12.0                     69.0           4.4
# 28         9.6           12.0                     37.0           4.2
# 29         2.0           12.0                     69.0           4.2
# 30         8.0           11.0                     60.0           1.1
# 31         5.8           11.0                     59.0          14.0
# 32         4.8            8.8                     73.6          22.4
# 33         7.0           14.0                     59.0           0.7
# 34         0.5            0.5                     86.0           0.5
# 35        15.0            9.7                     61.0          15.0
# 36         2.0           12.0                     69.0           4.2
# 37         0.9            7.0                     84.0           8.0
# 38         7.2           10.2                     59.6          17.2
# 39         2.0           13.0                     71.0           3.5
# 40        13.0           11.0                      4.0           3.5
# 41         0.2           17.5                      1.5           1.5
# 42        30.0           15.0                      0.8           0.1
# 43        24.0            5.9                      3.0           3.0
# 44        22.8           15.7                      0.8           0.8
# 45        15.0           12.0                      2.5           2.5
# 46        17.8            8.3                      3.0           3.0
# 47        23.0           20.0                      1.0           1.0
# 48        21.0           20.0                      0.0           0.0
# 49        23.0           18.0                      1.0           0.1
# 50        29.0           27.0                      0.5           0.5
# 51        17.8            8.3                      3.0           3.0
# 52        30.0           15.3                      0.8           0.1
# 53        24.0            5.9                      3.0           3.0
# 54        29.0            9.0                      2.0           2.0
# 55         0.2           10.0                      3.9           3.9
# 56        17.5           11.5                      6.0           6.0
# 57        29.0            9.0                      2.0           2.0
# 58        27.5           26.0                      0.1           0.1
# 59        34.5            7.0                      2.3           2.3

# %% [markdown]
# ### Definir los Segmentos del Mercado:
# Definimos algunos segmentos:
# * **Alta Energía:** Productos con más de 400 kcal por 100g.
# * **Bajo en Grasa:** Productos con menos de 10g de grasa por 100g.
# * **Alta Proteína:** Productos con más de 15g de proteínas por 100g.
# * **Carbohidratos Altos:** Productos con más de 50g de carbohidratos por 100g.

# %% [markdown]
# ### Análisis de Datos:
# A continuación, vamos a clasificar los productos en los segmentos definidos.

# %%
# Definir criterios para los segmentos
alta_energia = lambda x: x > 400
bajo_grasa = lambda x: x < 10
alta_proteina = lambda x: x > 15
altos_carbohidratos = lambda x: x > 50

# Agregar columna para segmentos
df_products['Segmento'] = 'N/A'

# Clasificar los productos
for index, row in df_products.iterrows():
    if alta_energia(row['Energía (kcal)']):
        df_products.at[index, 'Segmento'] = 'Alta Energía'
    elif bajo_grasa(row['Grasas (g)']):
        df_products.at[index, 'Segmento'] = 'Bajo en Grasa'
    elif alta_proteina(row['Proteínas (g)']):
        df_products.at[index, 'Segmento'] = 'Alta Proteína'
    elif altos_carbohidratos(row['Hidratos de Carbono (g)']):
        df_products.at[index, 'Segmento'] = 'Altos Carbohidratos'
    else:
        df_products.at[index, 'Segmento'] = 'Otro'

# Mostrar el DataFrame
print("Tabla de Información Nutricional de Productos:")
print(df_products)

# Guardar el DataFrame en un archivo CSV
csv_filename = 'productos_segmentados.csv'
df_products.to_csv(csv_filename, index=False)
print(f"\nLos datos han sido guardados en '{csv_filename}'.")
# Out:
# Tabla de Información Nutricional de Productos:
#                                              Producto   Categoría  \
# 0                          Chocolat noir 65% de cacao  chocolates
# 1                              70% Cacao noir intense  chocolates
# 2                                 Noir Excellence 90%  chocolates
# 3         Excellence 85% Cacao Chocolat Noir Puissant  chocolates
# 4                                 Edelbitter mild 85%  chocolates
# 5                      Extra dark chocolate 74% cacao  chocolates
# 6                                    Milka Lait Alpin  chocolates
# 7                   Excellence 70% Cocoa Intense Dark  chocolates
# 8                                      Nestlé Dessert  chocolates
# 9                 85% Cocoa Robust Dark Chocolate Bar  chocolates
# 10                               Doux 70% noir subtil  chocolates
# 11                             Ecuador Edelbitter 70%  chocolates
# 12                        Bio Chocolat Noir Cacao 70%  chocolates
# 13                          Noir - Noisettes Entières  chocolates
# 14                 Excellence 99% Cacao Noir Absolute  chocolates
# 15                                         Noir Extra  chocolates
# 16             Chocolat noir extra-fin, traditionnel.  chocolates
# 17        Chocolat noir 47% et pointe de fleur de sel  chocolates
# 18               Bio Chocolat Noir Equateur 85% cacao  chocolates
# 19                                           Čokoláda  chocolates
# 20                            Cruesli Mélange De Noix     cereals
# 21                                  Céréales Chocapic     cereals
# 22                          Oat Drink Barista Edition     cereals
# 23                            Haferflocken Extra zart     cereals
# 24                  Flocons d'avoine céréale complète     cereals
# 25                                  Ohne Zucker Hafer     cereals
# 26                                 Muesli Superfruits     cereals
# 27                                           Weetabix     cereals
# 28  Pain de mie grandes tranches Seigle & Graines ...     cereals
# 29        Weetabix produit à base de blé complet 100%     cereals
# 30                          Flocons d'avoine complète     cereals
# 31                      Muesli Raisin, Figue, Abricot     cereals
# 32                      NESTLE CHOCAPIC Céréales 750g     cereals
# 33                                     Copos de avena     cereals
# 34                                                        cereals
# 35                              Croustillant Chocolat     cereals
# 36                                           Weetabix     cereals
# 37                                        Corn Flakes     cereals
# 38                   Special Muesli 30% fruits & noix     cereals
# 39                                      Spaghetti n°5     cereals
# 40                             Ziegenfrischkäse Natur     cheeses
# 41                                     Carré frais 0%     cheeses
# 42                                  Caprice des dieux     cheeses
# 43  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 44                                Salakis 100% Brebis     cheeses
# 45                                        Carré frais     cheeses
# 46                                           St Môret     cheeses
# 47            La bûche Sainte-Maure (Poitou-Charentes     cheeses
# 48                           PRESIDENT CAMEMBERT 250g     cheeses
# 49                        Coulommiers Doux et Crémeux     cheeses
# 50             President emmental coeur de meule 250g     cheeses
# 51                    Le Goût Primeur format familial     cheeses
# 52                                  Caprice des dieux     cheeses
# 53  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 54                                          Kiri-Käse     cheeses
# 55                                               SKYR     cheeses
# 56                                   La vache qui rit     cheeses
# 57                            Kiri® Crème 12 portions     cheeses
# 58                Leerdammer original 8 tranches 200g     cheeses
# 59              L'original tartare ail & fines herbes     cheeses
#
#                                          Ingredientes  Energía (kcal)  \
# 0                                                                 559
# 1          cocoa paste, sugar, cocoa butter, vanilla,             566
# 2   cocoa mass, cocoa butter, low-fat cocoa, sugar...             592
# 3   Pâte de cacao, cacao maigre, beurre de cacao, ...             584
# 4   Kakaomasse, fettarmes Kakaopulver, Kakaobutter...             579
# 5   cocoa mass, sugar, cocoa butter, fat reduced c...             570
# 6   Sucre, beurre de cacao, pâte de cacao, LAIT éc...             539
# 7           Cocoa mass, sugar, cocoa butter, vanilla.             566
# 8   sugar, cocoa paste, cocoa butter, emulsifier s...             548
# 9   cocoa mass, fat-reduced cocoa, cocoa butter, d...             584
# 10  cocoa mass, sugar, cocoa butter, emulsifier (s...             610
# 11  Kakaomasse, Zucker, Kakaobutter, Emulgator: Le...             565
# 12  Pâte de cacao¹, sucre de canne¹, beurre de cac...             572
# 13  Sucre, pâte de cacao, NOISETTES (24%), beurre ...             569
# 14  Cocoa solids 99%, Cocoa paste, fat-reduced coc...             590
# 15  sugar, cocoa paste, cocoa butter, lean cocoa p...             508
# 16  Pâte de cacao, beurre de cacao, sucre, cacao m...             576
# 17  sugar, cocoa paste, cocoa butter, concentrated...             537
# 18  Pâte de cacao* Équateur, beurre de cacao*, suc...             639
# 19  sugar, cocoa paste, cocoa butter, emulsifier: ...             544
# 20  _avoine_ complète (32%), _blé_ complet (18%), ...             462
# 21  Blé complet 35,0%, chocolat en poudre 22,5% (s...             388
# 22  Water, _OATS_ 10%, rapeseed oil, acidity regul...              61
# 23                             soft whole-oat flakes,             372
# 24  Flocons d'_avoine_ complète issue de l'agricul...             362
# 25  Haferbasis (Wasser,  Hafer (8,7%)), Zichorienw...              40
# 26  Flocons d'_avoine_ complète 60 %, raisins secs...             357
# 27  wholegrain wheat (95%), malted barley extract,...             362
# 28  Farine de BLÉ* 41 % , eau, graines de lin brun...             297
# 29  _Blé_ complet (95%), extrait d'_orge_ maltée, ...             362
# 30                             100% Flocons d'avoine.             375
# 31  Flocons d'avoine* complète, Flocons de blé* co...             352
# 32  BLE complet 35,0%, chocolat en poudre 22,5% (s...             388
# 33                                Avena integral 100%             375
# 34                                        corn starch             355
# 35  Flocons d'avoine complète, Flocons de blé comp...             437
# 36  Wholegrain _Wheat_ (95%), Malted _Barley_ Extr...             362
# 37  corn, sugar, aroma of malt of barley, salt, vi...             378
# 38  Céréales complètes flocons d'avoine, flocons d...             362
# 39  Semoule de BLÉ dur, eau. Peut contenir des tra...             359
# 40                             Ziegenfrischkäse, Salz             177
# 41               Lait écrémé, sel, ferments lactiques              78
# 42  pasteurized cow's milk and cream from france, ...             333
# 43              _Fromage_ frais, sel de Guérande 1,1%             252
# 44                                       sheep cheese             272
# 45          whole milk, cream, salt, lactic ferments,             193
# 46  _lait_ et _crème_ pasteurisés (Origine: France...             205
# 47  goat's milk (origin france), salt, ferments, c...             291
# 48  LAIT (origine France), ferments lactiques et d...             269
# 49         cow's milk, salt, ferments (contain milk),             283
# 50          LAIT pasteurisé de vache , sel, ferments.             369
# 51  Lait et crème pasteurisés (Origine : France), ...             205
# 52  lait de vache pasteurisé de France, sel, ferme...             333
# 53                Fromage frais, sel de Guérande 1,1%             252
# 54  pasteurized fresh milk 53% (origin: france), c...             305
# 55  Lait écrémé, ferments lactiques (lait). Lait: ...              57
# 56  LAIT écrémé réhydraté (origine : France), FROM...             228
# 57  LAIT frais pasteurisé 53% (origine : France), ...             305
# 58  LAIT pasteurisé, sel, ferments LACTIQUES, enzy...             352
# 59  Lait et crème pasteurisés (origine: France), a...             348
#
#     Grasas (g)  Proteínas (g)  Hidratos de Carbono (g)  Azúcares (g)  \
# 0         41.0            6.8                     35.0          32.0
# 1         41.0            9.5                     34.0          30.0
# 2         55.0           10.0                     14.0           7.0
# 3         46.0           12.5                     22.0          15.0
# 4         46.8           10.8                     21.4          12.9
# 5         42.0           10.0                     32.0          26.0
# 6         31.0            6.5                     57.0          55.0
# 7         41.0            9.5                     34.0          30.0
# 8         34.1            6.0                     50.7          46.4
# 9         46.0           12.5                     22.0          15.0
# 10        48.0            6.9                     33.0          29.0
# 11        41.5            8.4                     33.8          27.2
# 12        41.6            8.5                     35.3          28.0
# 13        39.0            7.3                     43.0          40.0
# 14        51.0           15.0                      8.0           1.0
# 15        28.0            4.9                     55.0          52.0
# 16        46.0           10.0                     24.0          17.0
# 17        32.0            5.7                     52.0          47.0
# 18        55.3            9.0                     20.6          14.0
# 19        35.0            4.8                     48.0          45.6
# 20        19.0            8.5                     57.0          12.0
# 21         4.8            8.8                     73.6          22.4
# 22         3.0            1.1                      7.1           4.0
# 23         7.0           13.5                     58.7           0.7
# 24         7.1           11.0                     58.0           1.7
# 25         1.5            0.2                      5.8           0.0
# 26         6.0           11.0                     60.0          14.0
# 27         2.0           12.0                     69.0           4.4
# 28         9.6           12.0                     37.0           4.2
# 29         2.0           12.0                     69.0           4.2
# 30         8.0           11.0                     60.0           1.1
# 31         5.8           11.0                     59.0          14.0
# 32         4.8            8.8                     73.6          22.4
# 33         7.0           14.0                     59.0           0.7
# 34         0.5            0.5                     86.0           0.5
# 35        15.0            9.7                     61.0          15.0
# 36         2.0           12.0                     69.0           4.2
# 37         0.9            7.0                     84.0           8.0
# 38         7.2           10.2                     59.6          17.2
# 39         2.0           13.0                     71.0           3.5
# 40        13.0           11.0                      4.0           3.5
# 41         0.2           17.5                      1.5           1.5
# 42        30.0           15.0                      0.8           0.1
# 43        24.0            5.9                      3.0           3.0
# 44        22.8           15.7                      0.8           0.8
# 45        15.0           12.0                      2.5           2.5
# 46        17.8            8.3                      3.0           3.0
# 47        23.0           20.0                      1.0           1.0
# 48        21.0           20.0                      0.0           0.0
# 49        23.0           18.0                      1.0           0.1
# 50        29.0           27.0                      0.5           0.5
# 51        17.8            8.3                      3.0           3.0
# 52        30.0           15.3                      0.8           0.1
# 53        24.0            5.9                      3.0           3.0
# 54        29.0            9.0                      2.0           2.0
# 55         0.2           10.0                      3.9           3.9
# 56        17.5           11.5                      6.0           6.0
# 57        29.0            9.0                      2.0           2.0
# 58        27.5           26.0                      0.1           0.1
# 59        34.5            7.0                      2.3           2.3
#
#          Segmento
# 0    Alta Energía
# 1    Alta Energía
# 2    Alta Energía
# 3    Alta Energía
# 4    Alta Energía
# 5    Alta Energía
# 6    Alta Energía
# 7    Alta Energía
# 8    Alta Energía
# 9    Alta Energía
# 10   Alta Energía
# 11   Alta Energía
# 12   Alta Energía
# 13   Alta Energía
# 14   Alta Energía
# 15   Alta Energía
# 16   Alta Energía
# 17   Alta Energía
# 18   Alta Energía
# 19   Alta Energía
# 20   Alta Energía
# 21  Bajo en Grasa
# 22  Bajo en Grasa
# 23  Bajo en Grasa
# 24  Bajo en Grasa
# 25  Bajo en Grasa
# 26  Bajo en Grasa
# 27  Bajo en Grasa
# 28  Bajo en Grasa
# 29  Bajo en Grasa
# 30  Bajo en Grasa
# 31  Bajo en Grasa
# 32  Bajo en Grasa
# 33  Bajo en Grasa
# 34  Bajo en Grasa
# 35   Alta Energía
# 36  Bajo en Grasa
# 37  Bajo en Grasa
# 38  Bajo en Grasa
# 39  Bajo en Grasa
# 40           Otro
# 41  Bajo en Grasa
# 42           Otro
# 43           Otro
# 44  Alta Proteína
# 45           Otro
# 46           Otro
# 47  Alta Proteína
# 48  Alta Proteína
# 49  Alta Proteína
# 50  Alta Proteína
# 51           Otro
# 52  Alta Proteína
# 53           Otro
# 54           Otro
# 55  Bajo en Grasa
# 56           Otro
# 57           Otro
# 58  Alta Proteína
# 59           Otro
#
# Los datos han sido guardados en 'productos_segmentados.csv'.

# %% [markdown]
# ## 3. Transparencia y Confianza

# %%
import requests
import pandas as pd

# Función para obtener la información detallada de un producto por su ID
def get_product_info(product_id):
    url = f'https://world.openfoodfacts.org/api/v0/product/{product_id}.json'
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json().get('product', {})
    else:
        return None

# Función para buscar productos por categoría y recolectar detalles
def search_and_collect_products(categories, page_size=20):
    all_product_details = []
    
    for category in categories:
        # Buscar productos en la categoría
        products = search_products_by_category(category, page_size)
        
        for product in products:
            product_id = product.get('id', 'N/A')
            product_name = product.get('product_name', 'N/A')
            
            # Obtener información detallada del producto
            detailed_product = get_product_info(product_id)
            
            if detailed_product:
                product_details = {
                    'ID': product_id,
                    'Producto': product_name,
                    'Categoría': category,
                    'Ingredientes': detailed_product.get('ingredients_text', 'N/A'),
                    'Energía (kcal)': detailed_product.get('nutriments', {}).get('energy-kcal_100g', 'N/A'),
                    'Grasas (g)': detailed_product.get('nutriments', {}).get('fat_100g', 'N/A'),
                    'Proteínas (g)': detailed_product.get('nutriments', {}).get('proteins_100g', 'N/A'),
                    'Hidratos de Carbono (g)': detailed_product.get('nutriments', {}).get('carbohydrates_100g', 'N/A'),
                    'Azúcares (g)': detailed_product.get('nutriments', {}).get('sugars_100g', 'N/A')
                }
                all_product_details.append(product_details)
            else:
                print(f"No se encontró información detallada para el producto {product_id}.")
    
    return all_product_details

# Categorías a buscar
categories = ['chocolates', 'cereals', 'cheeses']

# Buscar productos y recolectar detalles
product_details = search_and_collect_products(categories)

# Crear un DataFrame con los detalles recolectados
df_products = pd.DataFrame(product_details)

# Mostrar el DataFrame
print("Tabla de Información Nutricional de Productos:")
print(df_products)
# Out:
# Tabla de Información Nutricional de Productos:
#                ID                                           Producto  \
# 0   3474341105842                         Chocolat noir 65% de cacao
# 1   3046920022651                             70% Cacao noir intense
# 2   3046920029759                                Noir Excellence 90%
# 3   3046920022606        Excellence 85% Cacao Chocolat Noir Puissant
# 4        20995553                                Edelbitter mild 85%
# 5        20022464                     Extra dark chocolate 74% cacao
# 6   3045140105502                                   Milka Lait Alpin
# 7   3046920028004                  Excellence 70% Cocoa Intense Dark
# 8   7613035040823                                     Nestlé Dessert
# 9   3046920028363                85% Cocoa Robust Dark Chocolate Bar
# 10  3046920029780                               Doux 70% noir subtil
# 11       20095291                             Ecuador Edelbitter 70%
# 12       40896243                        Bio Chocolat Noir Cacao 70%
# 13  7622210995087                          Noir - Noisettes Entières
# 14  3046920028721                 Excellence 99% Cacao Noir Absolute
# 15  3664346305860                                         Noir Extra
# 16  3046920010047             Chocolat noir extra-fin, traditionnel.
# 17  3046920027885        Chocolat noir 47% et pointe de fleur de sel
# 18       20713713               Bio Chocolat Noir Equateur 85% cacao
# 19       20022471                                           Čokoláda
# 20  3168930010265                            Cruesli Mélange De Noix
# 21  7613034626844                                  Céréales Chocapic
# 22  7394376616228                          Oat Drink Barista Edition
# 23       20003166                            Haferflocken Extra zart
# 24  3229820019307                  Flocons d'avoine céréale complète
# 25  5411188124689                                  Ohne Zucker Hafer
# 26  3229820782560                                 Muesli Superfruits
# 27  5010029000016                                           Weetabix
# 28  3760049798609  Pain de mie grandes tranches Seigle & Graines ...
# 29  5010029000023        Weetabix produit à base de blé complet 100%
# 30  3168930009078                          Flocons d'avoine complète
# 31  3229820129488                      Muesli Raisin, Figue, Abricot
# 32  7613034947611                      NESTLE CHOCAPIC Céréales 750g
# 33  4008713756661                                     Copos de avena
# 34  8712100338694
# 35  3229820160672                              Croustillant Chocolat
# 36  5010029000801                                           Weetabix
# 37  3159470000120                                        Corn Flakes
# 38  5010477348678                   Special Muesli 30% fruits & noix
# 39  8076800195057                                      Spaghetti n°5
# 40  4099200191041                             Ziegenfrischkäse Natur
# 41  3480341000674                                     Carré frais 0%
# 42  3161711001971                                  Caprice des dieux
# 43  3412290070101  Paysan Breton - Le Fromage Fouetté Madame Loïk...
# 44  3023260030928                                Salakis 100% Brebis
# 45  3480341000636                                        Carré frais
# 46  3272770098090                                           St Môret
# 47  3523230028431            La bûche Sainte-Maure (Poitou-Charentes
# 48  3228021170039                           PRESIDENT CAMEMBERT 250g
# 49  3176582033563                        Coulommiers Doux et Crémeux
# 50  3228021170022             President emmental coeur de meule 250g
# 51  3272770097642                    Le Goût Primeur format familial
# 52  3161711000622                                  Caprice des dieux
# 53  3412290070071  Paysan Breton - Le Fromage Fouetté Madame Loïk...
# 54  3073781131888                                          Kiri-Käse
# 55  3033491454080                                               SKYR
# 56  3073781192186                                   La vache qui rit
# 57  3073781131925                            Kiri® Crème 12 portions
# 58  8721800402055                Leerdammer original 8 tranches 200g
# 59  3272770094412              L'original tartare ail & fines herbes
#
#      Categoría                                       Ingredientes  \
# 0   chocolates
# 1   chocolates         cocoa paste, sugar, cocoa butter, vanilla,
# 2   chocolates  cocoa mass, cocoa butter, low-fat cocoa, sugar...
# 3   chocolates  Pâte de cacao, cacao maigre, beurre de cacao, ...
# 4   chocolates  Kakaomasse, fettarmes Kakaopulver, Kakaobutter...
# 5   chocolates  cocoa mass, sugar, cocoa butter, fat reduced c...
# 6   chocolates  Sucre, beurre de cacao, pâte de cacao, LAIT éc...
# 7   chocolates          Cocoa mass, sugar, cocoa butter, vanilla.
# 8   chocolates  sugar, cocoa paste, cocoa butter, emulsifier s...
# 9   chocolates  cocoa mass, fat-reduced cocoa, cocoa butter, d...
# 10  chocolates  cocoa mass, sugar, cocoa butter, emulsifier (s...
# 11  chocolates  Kakaomasse, Zucker, Kakaobutter, Emulgator: Le...
# 12  chocolates  Pâte de cacao¹, sucre de canne¹, beurre de cac...
# 13  chocolates  Sucre, pâte de cacao, NOISETTES (24%), beurre ...
# 14  chocolates  Cocoa solids 99%, Cocoa paste, fat-reduced coc...
# 15  chocolates  sugar, cocoa paste, cocoa butter, lean cocoa p...
# 16  chocolates  Pâte de cacao, beurre de cacao, sucre, cacao m...
# 17  chocolates  sugar, cocoa paste, cocoa butter, concentrated...
# 18  chocolates  Pâte de cacao* Équateur, beurre de cacao*, suc...
# 19  chocolates  sugar, cocoa paste, cocoa butter, emulsifier: ...
# 20     cereals  _avoine_ complète (32%), _blé_ complet (18%), ...
# 21     cereals  Blé complet 35,0%, chocolat en poudre 22,5% (s...
# 22     cereals  Water, _OATS_ 10%, rapeseed oil, acidity regul...
# 23     cereals                             soft whole-oat flakes,
# 24     cereals  Flocons d'_avoine_ complète issue de l'agricul...
# 25     cereals  Haferbasis (Wasser,  Hafer (8,7%)), Zichorienw...
# 26     cereals  Flocons d'_avoine_ complète 60 %, raisins secs...
# 27     cereals  wholegrain wheat (95%), malted barley extract,...
# 28     cereals  Farine de BLÉ* 41 % , eau, graines de lin brun...
# 29     cereals  _Blé_ complet (95%), extrait d'_orge_ maltée, ...
# 30     cereals                             100% Flocons d'avoine.
# 31     cereals  Flocons d'avoine* complète, Flocons de blé* co...
# 32     cereals  BLE complet 35,0%, chocolat en poudre 22,5% (s...
# 33     cereals                                Avena integral 100%
# 34     cereals                                        corn starch
# 35     cereals  Flocons d'avoine complète, Flocons de blé comp...
# 36     cereals  Wholegrain _Wheat_ (95%), Malted _Barley_ Extr...
# 37     cereals  corn, sugar, aroma of malt of barley, salt, vi...
# 38     cereals  Céréales complètes flocons d'avoine, flocons d...
# 39     cereals  Semoule de BLÉ dur, eau. Peut contenir des tra...
# 40     cheeses                             Ziegenfrischkäse, Salz
# 41     cheeses               Lait écrémé, sel, ferments lactiques
# 42     cheeses  pasteurized cow's milk and cream from france, ...
# 43     cheeses              _Fromage_ frais, sel de Guérande 1,1%
# 44     cheeses                                       sheep cheese
# 45     cheeses          whole milk, cream, salt, lactic ferments,
# 46     cheeses  _lait_ et _crème_ pasteurisés (Origine: France...
# 47     cheeses  goat's milk (origin france), salt, ferments, c...
# 48     cheeses  LAIT (origine France), ferments lactiques et d...
# 49     cheeses         cow's milk, salt, ferments (contain milk),
# 50     cheeses          LAIT pasteurisé de vache , sel, ferments.
# 51     cheeses  Lait et crème pasteurisés (Origine : France), ...
# 52     cheeses  lait de vache pasteurisé de France, sel, ferme...
# 53     cheeses                Fromage frais, sel de Guérande 1,1%
# 54     cheeses  pasteurized fresh milk 53% (origin: france), c...
# 55     cheeses  Lait écrémé, ferments lactiques (lait). Lait: ...
# 56     cheeses  LAIT écrémé réhydraté (origine : France), FROM...
# 57     cheeses  LAIT frais pasteurisé 53% (origine : France), ...
# 58     cheeses  LAIT pasteurisé, sel, ferments LACTIQUES, enzy...
# 59     cheeses  Lait et crème pasteurisés (origine: France), a...
#
#     Energía (kcal)  Grasas (g)  Proteínas (g)  Hidratos de Carbono (g)  \
# 0              559        41.0            6.8                     35.0
# 1              566        41.0            9.5                     34.0
# 2              592        55.0           10.0                     14.0
# 3              584        46.0           12.5                     22.0
# 4              579        46.8           10.8                     21.4
# 5              570        42.0           10.0                     32.0
# 6              539        31.0            6.5                     57.0
# 7              566        41.0            9.5                     34.0
# 8              548        34.1            6.0                     50.7
# 9              584        46.0           12.5                     22.0
# 10             610        48.0            6.9                     33.0
# 11             565        41.5            8.4                     33.8
# 12             572        41.6            8.5                     35.3
# 13             569        39.0            7.3                     43.0
# 14             590        51.0           15.0                      8.0
# 15             508        28.0            4.9                     55.0
# 16             576        46.0           10.0                     24.0
# 17             537        32.0            5.7                     52.0
# 18             639        55.3            9.0                     20.6
# 19             544        35.0            4.8                     48.0
# 20             462        19.0            8.5                     57.0
# 21             388         4.8            8.8                     73.6
# 22              61         3.0            1.1                      7.1
# 23             372         7.0           13.5                     58.7
# 24             362         7.1           11.0                     58.0
# 25              40         1.5            0.2                      5.8
# 26             357         6.0           11.0                     60.0
# 27             362         2.0           12.0                     69.0
# 28             297         9.6           12.0                     37.0
# 29             362         2.0           12.0                     69.0
# 30             375         8.0           11.0                     60.0
# 31             352         5.8           11.0                     59.0
# 32             388         4.8            8.8                     73.6
# 33             375         7.0           14.0                     59.0
# 34             355         0.5            0.5                     86.0
# 35             437        15.0            9.7                     61.0
# 36             362         2.0           12.0                     69.0
# 37             378         0.9            7.0                     84.0
# 38             362         7.2           10.2                     59.6
# 39             359         2.0           13.0                     71.0
# 40             177        13.0           11.0                      4.0
# 41              78         0.2           17.5                      1.5
# 42             333        30.0           15.0                      0.8
# 43             252        24.0            5.9                      3.0
# 44             272        22.8           15.7                      0.8
# 45             193        15.0           12.0                      2.5
# 46             205        17.8            8.3                      3.0
# 47             291        23.0           20.0                      1.0
# 48             269        21.0           20.0                      0.0
# 49             283        23.0           18.0                      1.0
# 50             369        29.0           27.0                      0.5
# 51             205        17.8            8.3                      3.0
# 52             333        30.0           15.3                      0.8
# 53             252        24.0            5.9                      3.0
# 54             305        29.0            9.0                      2.0
# 55              57         0.2           10.0                      3.9
# 56             228        17.5           11.5                      6.0
# 57             305        29.0            9.0                      2.0
# 58             352        27.5           26.0                      0.1
# 59             348        34.5            7.0                      2.3
#
#     Azúcares (g)
# 0           32.0
# 1           30.0
# 2            7.0
# 3           15.0
# 4           12.9
# 5           26.0
# 6           55.0
# 7           30.0
# 8           46.4
# 9           15.0
# 10          29.0
# 11          27.2
# 12          28.0
# 13          40.0
# 14           1.0
# 15          52.0
# 16          17.0
# 17          47.0
# 18          14.0
# 19          45.6
# 20          12.0
# 21          22.4
# 22           4.0
# 23           0.7
# 24           1.7
# 25           0.0
# 26          14.0
# 27           4.4
# 28           4.2
# 29           4.2
# 30           1.1
# 31          14.0
# 32          22.4
# 33           0.7
# 34           0.5
# 35          15.0
# 36           4.2
# 37           8.0
# 38          17.2
# 39           3.5
# 40           3.5
# 41           1.5
# 42           0.1
# 43           3.0
# 44           0.8
# 45           2.5
# 46           3.0
# 47           1.0
# 48           0.0
# 49           0.1
# 50           0.5
# 51           3.0
# 52           0.1
# 53           3.0
# 54           2.0
# 55           3.9
# 56           6.0
# 57           2.0
# 58           0.1
# 59           2.3

# %%
# Guardar el DataFrame en un archivo CSV
csv_filename = 'productos_transparencia.csv'
df_products.to_csv(csv_filename, index=False)
print(f"\nLos datos han sido guardados en '{csv_filename}'.")
# Out:
# Los datos han sido guardados en 'productos_transparencia.csv'.

# %% [markdown]
# ### 5. Campañas Educativas

# %%
import requests
import pandas as pd

def search_products_by_category(category, page_size=20):
    """Busca productos en una categoría específica en Open Food Facts."""
    url = f'https://world.openfoodfacts.org/category/{category}.json?page_size={page_size}'
    response = requests.get(url)
    
    if response.status_code == 200:
        products = response.json().get('products', [])
        return products
    else:
        return []

def get_product_info(product_id):
    """Obtiene la información detallada de un producto por su ID."""
    url = f'https://world.openfoodfacts.org/api/v0/product/{product_id}.json'
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json().get('product', {})
    else:
        return None

def collect_product_details(categories):
    """Recolecta los detalles nutricionales de productos en varias categorías."""
    all_product_details = []
    
    for category in categories:
        products = search_products_by_category(category)
        
        for product in products:
            product_id = product.get('id', 'N/A')
            product_name = product.get('product_name', 'N/A')
            
            detailed_product = get_product_info(product_id)
            
            if detailed_product:
                product_details = {
                    'Producto': product_name,
                    'Categoría': category,
                    'Ingredientes': detailed_product.get('ingredients_text', 'N/A'),
                    'Energía (kcal)': detailed_product.get('nutriments', {}).get('energy-kcal_100g', 'N/A'),
                    'Grasas (g)': detailed_product.get('nutriments', {}).get('fat_100g', 'N/A'),
                    'Proteínas (g)': detailed_product.get('nutriments', {}).get('proteins_100g', 'N/A'),
                    'Hidratos de Carbono (g)': detailed_product.get('nutriments', {}).get('carbohydrates_100g', 'N/A'),
                    'Azúcares (g)': detailed_product.get('nutriments', {}).get('sugars_100g', 'N/A')
                }
                all_product_details.append(product_details)
            else:
                print(f"No se encontró información detallada para el producto {product_id}.")
    
    return all_product_details

# Categorías a buscar
categories = ['chocolates', 'cereals', 'cheeses']

# Recolectar detalles de productos y construir el dataframe
product_details = collect_product_details(categories)

# Crear un DataFrame con los detalles recolectados
df_products = pd.DataFrame(product_details)

# Mostrar el DataFrame
print("Tabla de Información Nutricional de Productos:")
print(df_products)

# Crear contenido educativo
def create_educational_content(df):
    for index, row in df.iterrows():
        print(f"\n--- Campaña Educativa: {row['Producto']} ---")
        print(f"Categoría: {row['Categoría']}")
        print(f"Ingredientes: {row['Ingredientes']}")
        print("Valor nutricional por 100g:")
        print(f" - Energía (kcal): {row['Energía (kcal)']}")
        print(f" - Grasas (g): {row['Grasas (g)']}")
        print(f" - Proteínas (g): {row['Proteínas (g)']}")
        print(f" - Hidratos de Carbono (g): {row['Hidratos de Carbono (g)']}")
        print(f" - Azúcares (g): {row['Azúcares (g)']}")
        
        # Definir umbrales para contenido alto en azúcar, grasas y proteínas
        high_sugar_threshold = 22.5  # gramos por 100 gramos
        high_fat_threshold = 17.5    # gramos por 100 gramos
        low_protein_threshold = 5    # gramos por 100 gramos
        
        print("\nConsejo de Nutrición:")
        if row['Azúcares (g)'] != 'N/A' and row['Azúcares (g)'] > high_sugar_threshold:
            print("Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.")
        if row['Grasas (g)'] != 'N/A' and row['Grasas (g)'] > high_fat_threshold:
            print("Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.")
        if row['Proteínas (g)'] != 'N/A' and row['Proteínas (g)'] < low_protein_threshold:
            print("Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.")
        print("\n--- Fin de la Campaña Educativa ---")

# Generar contenido educativo para cada producto
create_educational_content(df_products)
# Out:
# Tabla de Información Nutricional de Productos:
#                                              Producto   Categoría  \
# 0                          Chocolat noir 65% de cacao  chocolates
# 1                              70% Cacao noir intense  chocolates
# 2                                 Noir Excellence 90%  chocolates
# 3         Excellence 85% Cacao Chocolat Noir Puissant  chocolates
# 4                                 Edelbitter mild 85%  chocolates
# 5                      Extra dark chocolate 74% cacao  chocolates
# 6                                    Milka Lait Alpin  chocolates
# 7                   Excellence 70% Cocoa Intense Dark  chocolates
# 8                                      Nestlé Dessert  chocolates
# 9                 85% Cocoa Robust Dark Chocolate Bar  chocolates
# 10                               Doux 70% noir subtil  chocolates
# 11                             Ecuador Edelbitter 70%  chocolates
# 12                        Bio Chocolat Noir Cacao 70%  chocolates
# 13                          Noir - Noisettes Entières  chocolates
# 14                 Excellence 99% Cacao Noir Absolute  chocolates
# 15                                         Noir Extra  chocolates
# 16             Chocolat noir extra-fin, traditionnel.  chocolates
# 17        Chocolat noir 47% et pointe de fleur de sel  chocolates
# 18               Bio Chocolat Noir Equateur 85% cacao  chocolates
# 19                                           Čokoláda  chocolates
# 20                            Cruesli Mélange De Noix     cereals
# 21                                  Céréales Chocapic     cereals
# 22                          Oat Drink Barista Edition     cereals
# 23                            Haferflocken Extra zart     cereals
# 24                  Flocons d'avoine céréale complète     cereals
# 25                                  Ohne Zucker Hafer     cereals
# 26                                 Muesli Superfruits     cereals
# 27                                           Weetabix     cereals
# 28  Pain de mie grandes tranches Seigle & Graines ...     cereals
# 29        Weetabix produit à base de blé complet 100%     cereals
# 30                          Flocons d'avoine complète     cereals
# 31                      Muesli Raisin, Figue, Abricot     cereals
# 32                      NESTLE CHOCAPIC Céréales 750g     cereals
# 33                                     Copos de avena     cereals
# 34                                                        cereals
# 35                              Croustillant Chocolat     cereals
# 36                                           Weetabix     cereals
# 37                                        Corn Flakes     cereals
# 38                   Special Muesli 30% fruits & noix     cereals
# 39                                      Spaghetti n°5     cereals
# 40                             Ziegenfrischkäse Natur     cheeses
# 41                                     Carré frais 0%     cheeses
# 42                                  Caprice des dieux     cheeses
# 43  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 44                                Salakis 100% Brebis     cheeses
# 45                                        Carré frais     cheeses
# 46                                           St Môret     cheeses
# 47            La bûche Sainte-Maure (Poitou-Charentes     cheeses
# 48                           PRESIDENT CAMEMBERT 250g     cheeses
# 49                        Coulommiers Doux et Crémeux     cheeses
# 50             President emmental coeur de meule 250g     cheeses
# 51                    Le Goût Primeur format familial     cheeses
# 52                                  Caprice des dieux     cheeses
# 53  Paysan Breton - Le Fromage Fouetté Madame Loïk...     cheeses
# 54                                          Kiri-Käse     cheeses
# 55                                               SKYR     cheeses
# 56                                   La vache qui rit     cheeses
# 57                            Kiri® Crème 12 portions     cheeses
# 58                Leerdammer original 8 tranches 200g     cheeses
# 59              L'original tartare ail & fines herbes     cheeses
#
#                                          Ingredientes  Energía (kcal)  \
# 0                                                                 559
# 1          cocoa paste, sugar, cocoa butter, vanilla,             566
# 2   cocoa mass, cocoa butter, low-fat cocoa, sugar...             592
# 3   Pâte de cacao, cacao maigre, beurre de cacao, ...             584
# 4   Kakaomasse, fettarmes Kakaopulver, Kakaobutter...             579
# 5   cocoa mass, sugar, cocoa butter, fat reduced c...             570
# 6   Sucre, beurre de cacao, pâte de cacao, LAIT éc...             539
# 7           Cocoa mass, sugar, cocoa butter, vanilla.             566
# 8   sugar, cocoa paste, cocoa butter, emulsifier s...             548
# 9   cocoa mass, fat-reduced cocoa, cocoa butter, d...             584
# 10  cocoa mass, sugar, cocoa butter, emulsifier (s...             610
# 11  Kakaomasse, Zucker, Kakaobutter, Emulgator: Le...             565
# 12  Pâte de cacao¹, sucre de canne¹, beurre de cac...             572
# 13  Sucre, pâte de cacao, NOISETTES (24%), beurre ...             569
# 14  Cocoa solids 99%, Cocoa paste, fat-reduced coc...             590
# 15  sugar, cocoa paste, cocoa butter, lean cocoa p...             508
# 16  Pâte de cacao, beurre de cacao, sucre, cacao m...             576
# 17  sugar, cocoa paste, cocoa butter, concentrated...             537
# 18  Pâte de cacao* Équateur, beurre de cacao*, suc...             639
# 19  sugar, cocoa paste, cocoa butter, emulsifier: ...             544
# 20  _avoine_ complète (32%), _blé_ complet (18%), ...             462
# 21  Blé complet 35,0%, chocolat en poudre 22,5% (s...             388
# 22  Water, _OATS_ 10%, rapeseed oil, acidity regul...              61
# 23                             soft whole-oat flakes,             372
# 24  Flocons d'_avoine_ complète issue de l'agricul...             362
# 25  Haferbasis (Wasser,  Hafer (8,7%)), Zichorienw...              40
# 26  Flocons d'_avoine_ complète 60 %, raisins secs...             357
# 27  wholegrain wheat (95%), malted barley extract,...             362
# 28  Farine de BLÉ* 41 % , eau, graines de lin brun...             297
# 29  _Blé_ complet (95%), extrait d'_orge_ maltée, ...             362
# 30                             100% Flocons d'avoine.             375
# 31  Flocons d'avoine* complète, Flocons de blé* co...             352
# 32  BLE complet 35,0%, chocolat en poudre 22,5% (s...             388
# 33                                Avena integral 100%             375
# 34                                        corn starch             355
# 35  Flocons d'avoine complète, Flocons de blé comp...             437
# 36  Wholegrain _Wheat_ (95%), Malted _Barley_ Extr...             362
# 37  corn, sugar, aroma of malt of barley, salt, vi...             378
# 38  Céréales complètes flocons d'avoine, flocons d...             362
# 39  Semoule de BLÉ dur, eau. Peut contenir des tra...             359
# 40                             Ziegenfrischkäse, Salz             177
# 41               Lait écrémé, sel, ferments lactiques              78
# 42  pasteurized cow's milk and cream from france, ...             333
# 43              _Fromage_ frais, sel de Guérande 1,1%             252
# 44                                       sheep cheese             272
# 45          whole milk, cream, salt, lactic ferments,             193
# 46  _lait_ et _crème_ pasteurisés (Origine: France...             205
# 47  goat's milk (origin france), salt, ferments, c...             291
# 48  LAIT (origine France), ferments lactiques et d...             269
# 49         cow's milk, salt, ferments (contain milk),             283
# 50          LAIT pasteurisé de vache , sel, ferments.             369
# 51  Lait et crème pasteurisés (Origine : France), ...             205
# 52  lait de vache pasteurisé de France, sel, ferme...             333
# 53                Fromage frais, sel de Guérande 1,1%             252
# 54  pasteurized fresh milk 53% (origin: france), c...             305
# 55  Lait écrémé, ferments lactiques (lait). Lait: ...              57
# 56  LAIT écrémé réhydraté (origine : France), FROM...             228
# 57  LAIT frais pasteurisé 53% (origine : France), ...             305
# 58  LAIT pasteurisé, sel, ferments LACTIQUES, enzy...             352
# 59  Lait et crème pasteurisés (origine: France), a...             348
#
#     Grasas (g)  Proteínas (g)  Hidratos de Carbono (g)  Azúcares (g)
# 0         41.0            6.8                     35.0          32.0
# 1         41.0            9.5                     34.0          30.0
# 2         55.0           10.0                     14.0           7.0
# 3         46.0           12.5                     22.0          15.0
# 4         46.8           10.8                     21.4          12.9
# 5         42.0           10.0                     32.0          26.0
# 6         31.0            6.5                     57.0          55.0
# 7         41.0            9.5                     34.0          30.0
# 8         34.1            6.0                     50.7          46.4
# 9         46.0           12.5                     22.0          15.0
# 10        48.0            6.9                     33.0          29.0
# 11        41.5            8.4                     33.8          27.2
# 12        41.6            8.5                     35.3          28.0
# 13        39.0            7.3                     43.0          40.0
# 14        51.0           15.0                      8.0           1.0
# 15        28.0            4.9                     55.0          52.0
# 16        46.0           10.0                     24.0          17.0
# 17        32.0            5.7                     52.0          47.0
# 18        55.3            9.0                     20.6          14.0
# 19        35.0            4.8                     48.0          45.6
# 20        19.0            8.5                     57.0          12.0
# 21         4.8            8.8                     73.6          22.4
# 22         3.0            1.1                      7.1           4.0
# 23         7.0           13.5                     58.7           0.7
# 24         7.1           11.0                     58.0           1.7
# 25         1.5            0.2                      5.8           0.0
# 26         6.0           11.0                     60.0          14.0
# 27         2.0           12.0                     69.0           4.4
# 28         9.6           12.0                     37.0           4.2
# 29         2.0           12.0                     69.0           4.2
# 30         8.0           11.0                     60.0           1.1
# 31         5.8           11.0                     59.0          14.0
# 32         4.8            8.8                     73.6          22.4
# 33         7.0           14.0                     59.0           0.7
# 34         0.5            0.5                     86.0           0.5
# 35        15.0            9.7                     61.0          15.0
# 36         2.0           12.0                     69.0           4.2
# 37         0.9            7.0                     84.0           8.0
# 38         7.2           10.2                     59.6          17.2
# 39         2.0           13.0                     71.0           3.5
# 40        13.0           11.0                      4.0           3.5
# 41         0.2           17.5                      1.5           1.5
# 42        30.0           15.0                      0.8           0.1
# 43        24.0            5.9                      3.0           3.0
# 44        22.8           15.7                      0.8           0.8
# 45        15.0           12.0                      2.5           2.5
# 46        17.8            8.3                      3.0           3.0
# 47        23.0           20.0                      1.0           1.0
# 48        21.0           20.0                      0.0           0.0
# 49        23.0           18.0                      1.0           0.1
# 50        29.0           27.0                      0.5           0.5
# 51        17.8            8.3                      3.0           3.0
# 52        30.0           15.3                      0.8           0.1
# 53        24.0            5.9                      3.0           3.0
# 54        29.0            9.0                      2.0           2.0
# 55         0.2           10.0                      3.9           3.9
# 56        17.5           11.5                      6.0           6.0
# 57        29.0            9.0                      2.0           2.0
# 58        27.5           26.0                      0.1           0.1
# 59        34.5            7.0                      2.3           2.3
#
# Los datos han sido guardados en 'productos_educativos.csv'.
#
# --- Campaña Educativa: Chocolat noir 65% de cacao ---
# Categoría: chocolates
# Ingredientes:
# Valor nutricional por 100g:
#  - Energía (kcal): 559
#  - Grasas (g): 41.0
#  - Proteínas (g): 6.8
#  - Hidratos de Carbono (g): 35.0
#  - Azúcares (g): 32.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: 70% Cacao noir intense ---
# Categoría: chocolates
# Ingredientes: cocoa paste, sugar, cocoa butter, vanilla,
# Valor nutricional por 100g:
#  - Energía (kcal): 566
#  - Grasas (g): 41.0
#  - Proteínas (g): 9.5
#  - Hidratos de Carbono (g): 34.0
#  - Azúcares (g): 30.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Noir Excellence 90% ---
# Categoría: chocolates
# Ingredientes: cocoa mass, cocoa butter, low-fat cocoa, sugar, vanilla,
# Valor nutricional por 100g:
#  - Energía (kcal): 592
#  - Grasas (g): 55.0
#  - Proteínas (g): 10.0
#  - Hidratos de Carbono (g): 14.0
#  - Azúcares (g): 7.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Excellence 85% Cacao Chocolat Noir Puissant ---
# Categoría: chocolates
# Ingredientes: Pâte de cacao, cacao maigre, beurre de cacao, cassonade, vanille. Peut contenir du lait, des fruits à coque, du soja et des graines de sésame.
# Valor nutricional por 100g:
#  - Energía (kcal): 584
#  - Grasas (g): 46.0
#  - Proteínas (g): 12.5
#  - Hidratos de Carbono (g): 22.0
#  - Azúcares (g): 15.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Edelbitter mild 85% ---
# Categoría: chocolates
# Ingredientes: Kakaomasse, fettarmes Kakaopulver, Kakaobutter, Zucker, Emulgator: Lecithine (Soja); Vanilleextrakt
# Valor nutricional por 100g:
#  - Energía (kcal): 579
#  - Grasas (g): 46.8
#  - Proteínas (g): 10.8
#  - Hidratos de Carbono (g): 21.4
#  - Azúcares (g): 12.9
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Extra dark chocolate 74% cacao ---
# Categoría: chocolates
# Ingredientes: cocoa mass, sugar, cocoa butter, fat reduced cocoa powder, emulsifier: lecithins (soya), natural vanilla flavouring, dark chocolate contains: cocoa solids 74% minimum,
# Valor nutricional por 100g:
#  - Energía (kcal): 570
#  - Grasas (g): 42.0
#  - Proteínas (g): 10.0
#  - Hidratos de Carbono (g): 32.0
#  - Azúcares (g): 26.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Milka Lait Alpin ---
# Categoría: chocolates
# Ingredientes: Sucre, beurre de cacao, pâte de cacao, LAIT écrémé en poudre, lactosérum en poudre (de LAIT), BEURRE concentré, émulsifiant (lécithines de SOJA), pâte de NOISETTE, arôme.
# Valor nutricional por 100g:
#  - Energía (kcal): 539
#  - Grasas (g): 31.0
#  - Proteínas (g): 6.5
#  - Hidratos de Carbono (g): 57.0
#  - Azúcares (g): 55.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Excellence 70% Cocoa Intense Dark ---
# Categoría: chocolates
# Ingredientes: Cocoa mass, sugar, cocoa butter, vanilla.
# Valor nutricional por 100g:
#  - Energía (kcal): 566
#  - Grasas (g): 41.0
#  - Proteínas (g): 9.5
#  - Hidratos de Carbono (g): 34.0
#  - Azúcares (g): 30.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Nestlé Dessert ---
# Categoría: chocolates
# Ingredientes: sugar, cocoa paste, cocoa butter, emulsifier sunflower lecithin, natural vanilla aroma madagascar, cocoa: 52% minimum, may contain: nuts, milk,
# Valor nutricional por 100g:
#  - Energía (kcal): 548
#  - Grasas (g): 34.1
#  - Proteínas (g): 6.0
#  - Hidratos de Carbono (g): 50.7
#  - Azúcares (g): 46.4
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: 85% Cocoa Robust Dark Chocolate Bar ---
# Categoría: chocolates
# Ingredientes: cocoa mass, fat-reduced cocoa, cocoa butter, demerara sugar, vanilla
# Valor nutricional por 100g:
#  - Energía (kcal): 584
#  - Grasas (g): 46.0
#  - Proteínas (g): 12.5
#  - Hidratos de Carbono (g): 22.0
#  - Azúcares (g): 15.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Doux 70% noir subtil ---
# Categoría: chocolates
# Ingredientes: cocoa mass, sugar, cocoa butter, emulsifier (soya lecithin), vanilla, may contain hazelnuts, almonds, milk,
# Valor nutricional por 100g:
#  - Energía (kcal): 610
#  - Grasas (g): 48.0
#  - Proteínas (g): 6.9
#  - Hidratos de Carbono (g): 33.0
#  - Azúcares (g): 29.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Ecuador Edelbitter 70% ---
# Categoría: chocolates
# Ingredientes: Kakaomasse, Zucker, Kakaobutter, Emulgator: Lecithine (_Soja_); Vanilleextrakt.
# Valor nutricional por 100g:
#  - Energía (kcal): 565
#  - Grasas (g): 41.5
#  - Proteínas (g): 8.4
#  - Hidratos de Carbono (g): 33.8
#  - Azúcares (g): 27.2
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Bio Chocolat Noir Cacao 70% ---
# Categoría: chocolates
# Ingredientes: Pâte de cacao¹, sucre de canne¹, beurre de cacao¹, émulsifiant : lécithines (_soja_)¹. ¹ingrédient issu de l'agriculture biologique.
# Valor nutricional por 100g:
#  - Energía (kcal): 572
#  - Grasas (g): 41.6
#  - Proteínas (g): 8.5
#  - Hidratos de Carbono (g): 35.3
#  - Azúcares (g): 28.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Noir - Noisettes Entières ---
# Categoría: chocolates
# Ingredientes: Sucre, pâte de cacao, NOISETTES (24%), beurre de cacao, BEURRE concentré, émulsifiant (lécithines de SOJA), arôme naturel de vanille, LAIT écrémé en poudre.
# Valor nutricional por 100g:
#  - Energía (kcal): 569
#  - Grasas (g): 39.0
#  - Proteínas (g): 7.3
#  - Hidratos de Carbono (g): 43.0
#  - Azúcares (g): 40.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Excellence 99% Cacao Noir Absolute ---
# Categoría: chocolates
# Ingredientes: Cocoa solids 99%, Cocoa paste, fat-reduced cocoa, cocoa butter, demerara sugar. May contain nuts, milk and soya.
# Valor nutricional por 100g:
#  - Energía (kcal): 590
#  - Grasas (g): 51.0
#  - Proteínas (g): 15.0
#  - Hidratos de Carbono (g): 8.0
#  - Azúcares (g): 1.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Noir Extra ---
# Categoría: chocolates
# Ingredientes: sugar, cocoa paste, cocoa butter, lean cocoa powder, emulsifier (soy lecithin), flavouring, skimmed milk powder, cocoa: 47% minimum, may contain wheat, barley and nuts,
# Valor nutricional por 100g:
#  - Energía (kcal): 508
#  - Grasas (g): 28.0
#  - Proteínas (g): 4.9
#  - Hidratos de Carbono (g): 55.0
#  - Azúcares (g): 52.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
# Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Chocolat noir extra-fin, traditionnel. ---
# Categoría: chocolates
# Ingredientes: Pâte de cacao, beurre de cacao, sucre, cacao maigre, beurre laitier concentré. Peut contenir des noisettes, des amandes et d'autres fruits à coque, du lait, du soja.
# Valor nutricional por 100g:
#  - Energía (kcal): 576
#  - Grasas (g): 46.0
#  - Proteínas (g): 10.0
#  - Hidratos de Carbono (g): 24.0
#  - Azúcares (g): 17.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Chocolat noir 47% et pointe de fleur de sel ---
# Categoría: chocolates
# Ingredientes: sugar, cocoa paste, cocoa butter, concentrated dairy butter, emulsifier (soy lecithin), fleur de sel 0,3%, aroma (vanilla),
# cocoa: 47% minimum,
# Valor nutricional por 100g:
#  - Energía (kcal): 537
#  - Grasas (g): 32.0
#  - Proteínas (g): 5.7
#  - Hidratos de Carbono (g): 52.0
#  - Azúcares (g): 47.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Bio Chocolat Noir Equateur 85% cacao ---
# Categoría: chocolates
# Ingredientes: Pâte de cacao* Équateur, beurre de cacao*, sucre*, extrait de vanille*
# Valor nutricional por 100g:
#  - Energía (kcal): 639
#  - Grasas (g): 55.3
#  - Proteínas (g): 9.0
#  - Hidratos de Carbono (g): 20.6
#  - Azúcares (g): 14.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Čokoláda ---
# Categoría: chocolates
# Ingredientes: sugar, cocoa paste, cocoa butter, emulsifier: lecithins (sunflower), natural vanilla flavour,
# Valor nutricional por 100g:
#  - Energía (kcal): 544
#  - Grasas (g): 35.0
#  - Proteínas (g): 4.8
#  - Hidratos de Carbono (g): 48.0
#  - Azúcares (g): 45.6
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en azúcares. Considera consumirlo con moderación.
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
# Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Cruesli Mélange De Noix ---
# Categoría: cereals
# Ingredientes: _avoine_ complète (32%), _blé_ complet (18%), sirop de glucose, huile de tournesol, sucre, _amandes_ grillées (4,2%), _noisettes_ (4%), oligofructose, _noix de Pécan_ (1,5%), farine de _blé_, farine de riz, _noix du Brésil_ (1%), miel, arômes naturels, antioxydant (tocophérol).
# Valor nutricional por 100g:
#  - Energía (kcal): 462
#  - Grasas (g): 19.0
#  - Proteínas (g): 8.5
#  - Hidratos de Carbono (g): 57.0
#  - Azúcares (g): 12.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Céréales Chocapic ---
# Categoría: cereals
# Ingredientes: Blé complet 35,0%, chocolat en poudre 22,5% (sucre, cacao en poudre), farine de blé 17,0%, semoule de maïs, sirop de glucose, sucre, extrait de malt d'orge (orge, orge malté), contient de l'huile de tournesol et/ou de palme, carbonate de calcium, émulsifiant : lécithines; sel, arômes naturels, fer, vitamines B3, B5, D, B6, B1, B2 et B9.
# Valor nutricional por 100g:
#  - Energía (kcal): 388
#  - Grasas (g): 4.8
#  - Proteínas (g): 8.8
#  - Hidratos de Carbono (g): 73.6
#  - Azúcares (g): 22.4
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Oat Drink Barista Edition ---
# Categoría: cereals
# Ingredientes: Water, _OATS_ 10%, rapeseed oil, acidity regulator (dipotassium phosphate), minerals (calcium carbonate, potassium iodide), salt, vitamins (D2, riboflavin and B12).
# Valor nutricional por 100g:
#  - Energía (kcal): 61
#  - Grasas (g): 3.0
#  - Proteínas (g): 1.1
#  - Hidratos de Carbono (g): 7.1
#  - Azúcares (g): 4.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Haferflocken Extra zart ---
# Categoría: cereals
# Ingredientes: soft whole-oat flakes,
# Valor nutricional por 100g:
#  - Energía (kcal): 372
#  - Grasas (g): 7.0
#  - Proteínas (g): 13.5
#  - Hidratos de Carbono (g): 58.7
#  - Azúcares (g): 0.7
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Flocons d'avoine céréale complète ---
# Categoría: cereals
# Ingredientes: Flocons d'_avoine_ complète issue de l'agriculture biologique,
# Valor nutricional por 100g:
#  - Energía (kcal): 362
#  - Grasas (g): 7.1
#  - Proteínas (g): 11.0
#  - Hidratos de Carbono (g): 58.0
#  - Azúcares (g): 1.7
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Ohne Zucker Hafer ---
# Categoría: cereals
# Ingredientes: Haferbasis (Wasser,  Hafer (8,7%)), Zichorienwurzelfasern, Sonnenblumenöl, Calciumcarbonat, Meersalz, Stabilisator (Gellan), Vitamine (B2, B12, D2)
# Valor nutricional por 100g:
#  - Energía (kcal): 40
#  - Grasas (g): 1.5
#  - Proteínas (g): 0.2
#  - Hidratos de Carbono (g): 5.8
#  - Azúcares (g): 0.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Muesli Superfruits ---
# Categoría: cereals
# Ingredientes: Flocons d'_avoine_ complète 60 %, raisins secs* 18 % (raisins secs*, huile de tournesol*), flocons d'_épeautre_* complets (_blé_) 12 %, flocons de _blé_* complet toasté 5 %, amandes* entières 3 %, canneberges lyophilisées* 0,7 %, cassis lyophilisés* 0,7 %, myrtilles lyophilisées* 0,7 %,
# Valor nutricional por 100g:
#  - Energía (kcal): 357
#  - Grasas (g): 6.0
#  - Proteínas (g): 11.0
#  - Hidratos de Carbono (g): 60.0
#  - Azúcares (g): 14.0
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Weetabix ---
# Categoría: cereals
# Ingredientes: wholegrain wheat (95%), malted barley extract, sugar, salt, niacin, iron, riboflavin (b2), thiamin (bi), acid,
# Valor nutricional por 100g:
#  - Energía (kcal): 362
#  - Grasas (g): 2.0
#  - Proteínas (g): 12.0
#  - Hidratos de Carbono (g): 69.0
#  - Azúcares (g): 4.4
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Pain de mie grandes tranches Seigle & Graines 500g ---
# Categoría: cereals
# Ingredientes: Farine de BLÉ* 41 % , eau, graines de lin brun 6,1 %, graines de lin jaune 6,1 %, graines de tournesol décortiquées 6 %, farine de SEIGLE 5,1 %, GLUTEN DE BLÉ, farine d'ORGE maltée torréfiée, levure, extrait de malt d'ORGE, sel, vinaigre, arôme naturel (contient alcool), conservateur : propionate de calcium, antioxydant : extrait d'acérola. Traces éventuelles d'œufs, lait, graines de sésame, soja et moutarde. * Ingrédient issu du commerce équitable français.
# Valor nutricional por 100g:
#  - Energía (kcal): 297
#  - Grasas (g): 9.6
#  - Proteínas (g): 12.0
#  - Hidratos de Carbono (g): 37.0
#  - Azúcares (g): 4.2
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Weetabix produit à base de blé complet 100% ---
# Categoría: cereals
# Ingredientes: _Blé_ complet (95%), extrait d'_orge_ maltée, sucre, sel, niacine, fer, vitamines B2, B1 et B9.
# Valor nutricional por 100g:
#  - Energía (kcal): 362
#  - Grasas (g): 2.0
#  - Proteínas (g): 12.0
#  - Hidratos de Carbono (g): 69.0
#  - Azúcares (g): 4.2
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Flocons d'avoine complète ---
# Categoría: cereals
# Ingredientes: 100% Flocons d'avoine.
# Valor nutricional por 100g:
#  - Energía (kcal): 375
#  - Grasas (g): 8.0
#  - Proteínas (g): 11.0
#  - Hidratos de Carbono (g): 60.0
#  - Azúcares (g): 1.1
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Muesli Raisin, Figue, Abricot ---
# Categoría: cereals
# Ingredientes: Flocons d'avoine* complète, Flocons de blé* complet, Raisins 12% (raisins*, huile de tournesol*), Figues* séchées 8% (figues*, farine de riz*), Pétales de maïs*, Flocons d'épeautre* complet (blé), Abricots* secs 3% (abricots*, farine de riz*) ✔Graines de tournesol*, Pétales d'épeautre* complet (blé), Graines de lin*, Graines de courge*.
#  Peut contenir des traces de lait, de fruits à coque, de graines de sésame et de soja. *Ingrédients biologiques.
# Valor nutricional por 100g:
#  - Energía (kcal): 352
#  - Grasas (g): 5.8
#  - Proteínas (g): 11.0
#  - Hidratos de Carbono (g): 59.0
#  - Azúcares (g): 14.0
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: NESTLE CHOCAPIC Céréales 750g ---
# Categoría: cereals
# Ingredientes: BLE complet 35,0%, chocolat en poudre 22,5% (sucre, cacao en poudre*), farine de BLE 17,0%, semoule de maïs, sirop de glucose, sucre, extrait de malt d'ORGE (ORGE, ORGE malté), contient de l'huile de tournesol et/ou de palme, carbonate de calcium, émulsifiant : lécithine ; sel, arômes naturels, fer, vitamines B3, B5, D, B6, B1, B2 et B9. Peut contenir du LAIT et des FRUITS A COQUE.* Bilan massique certifié rainforest Alliance www.ra.org/fr.
# Valor nutricional por 100g:
#  - Energía (kcal): 388
#  - Grasas (g): 4.8
#  - Proteínas (g): 8.8
#  - Hidratos de Carbono (g): 73.6
#  - Azúcares (g): 22.4
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Copos de avena ---
# Categoría: cereals
# Ingredientes: Avena integral 100%
# Valor nutricional por 100g:
#  - Energía (kcal): 375
#  - Grasas (g): 7.0
#  - Proteínas (g): 14.0
#  - Hidratos de Carbono (g): 59.0
#  - Azúcares (g): 0.7
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa:  ---
# Categoría: cereals
# Ingredientes: corn starch
# Valor nutricional por 100g:
#  - Energía (kcal): 355
#  - Grasas (g): 0.5
#  - Proteínas (g): 0.5
#  - Hidratos de Carbono (g): 86.0
#  - Azúcares (g): 0.5
#
# Consejo de Nutrición:
# Este producto tiene un contenido bajo en proteínas. Considera añadir más alimentos ricos en proteínas a tu dieta.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Croustillant Chocolat ---
# Categoría: cereals
# Ingredientes: Flocons d'avoine complète, Flocons de blé complet, Chocolat noir 10% (pâte de cacao, sucre de canne non raffiné, beurre de cacao), Riz extrudé (farine de riz), Sucre de canne non raffiné, Farine de blé, Huile de tournesol, Miel, Stabilisant: gomme d'acacia, Mélasses, Flocons de noix de coco, Sel marin, Cannelle, Antioxydant: extrait riche en tocophérols
# Valor nutricional por 100g:
#  - Energía (kcal): 437
#  - Grasas (g): 15.0
#  - Proteínas (g): 9.7
#  - Hidratos de Carbono (g): 61.0
#  - Azúcares (g): 15.0
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Weetabix ---
# Categoría: cereals
# Ingredientes: Wholegrain _Wheat_ (95%), Malted _Barley_ Extract, Sugar, Salt, Niacin, Iron, Riboflavin (B2), Thiamin (B1), Folic Acid.
# Valor nutricional por 100g:
#  - Energía (kcal): 362
#  - Grasas (g): 2.0
#  - Proteínas (g): 12.0
#  - Hidratos de Carbono (g): 69.0
#  - Azúcares (g): 4.2
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Corn Flakes ---
# Categoría: cereals
# Ingredientes: corn, sugar, aroma of malt of barley, salt, vitamins and minerals : vitamin b3/pp, vitamin b6, vitamin b2, vitamin b1, vitamin b9, vitamin d, vitamin b12, iron,
# Valor nutricional por 100g:
#  - Energía (kcal): 378
#  - Grasas (g): 0.9
#  - Proteínas (g): 7.0
#  - Hidratos de Carbono (g): 84.0
#  - Azúcares (g): 8.0
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Special Muesli 30% fruits & noix ---
# Categoría: cereals
# Ingredientes: Céréales complètes flocons d'avoine, flocons de blé, flocons de blé grillés noix raisins secs, raisins de sultane, abricots secs hachés, tranches de pommes séchées, éclats de noix de coco grillés, noisettes hachées grillées, amandes effilées flocons d'orge, graines de tournesol.
# Valor nutricional por 100g:
#  - Energía (kcal): 362
#  - Grasas (g): 7.2
#  - Proteínas (g): 10.2
#  - Hidratos de Carbono (g): 59.6
#  - Azúcares (g): 17.2
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Spaghetti n°5 ---
# Categoría: cereals
# Ingredientes: Semoule de BLÉ dur, eau. Peut contenir des traces de SOJA et de MOUTARDE.
# Valor nutricional por 100g:
#  - Energía (kcal): 359
#  - Grasas (g): 2.0
#  - Proteínas (g): 13.0
#  - Hidratos de Carbono (g): 71.0
#  - Azúcares (g): 3.5
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Ziegenfrischkäse Natur ---
# Categoría: cheeses
# Ingredientes: Ziegenfrischkäse, Salz
# Valor nutricional por 100g:
#  - Energía (kcal): 177
#  - Grasas (g): 13.0
#  - Proteínas (g): 11.0
#  - Hidratos de Carbono (g): 4.0
#  - Azúcares (g): 3.5
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Carré frais 0% ---
# Categoría: cheeses
# Ingredientes: Lait écrémé, sel, ferments lactiques
# Valor nutricional por 100g:
#  - Energía (kcal): 78
#  - Grasas (g): 0.2
#  - Proteínas (g): 17.5
#  - Hidratos de Carbono (g): 1.5
#  - Azúcares (g): 1.5
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Caprice des dieux ---
# Categoría: cheeses
# Ingredientes: pasteurized cow's milk and cream from france, salt, lactic ferments (milk)
# Valor nutricional por 100g:
#  - Energía (kcal): 333
#  - Grasas (g): 30.0
#  - Proteínas (g): 15.0
#  - Hidratos de Carbono (g): 0.8
#  - Azúcares (g): 0.1
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Paysan Breton - Le Fromage Fouetté Madame Loïk - Nature au Sel de Guérande ---
# Categoría: cheeses
# Ingredientes: _Fromage_ frais, sel de Guérande 1,1%
# Valor nutricional por 100g:
#  - Energía (kcal): 252
#  - Grasas (g): 24.0
#  - Proteínas (g): 5.9
#  - Hidratos de Carbono (g): 3.0
#  - Azúcares (g): 3.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Salakis 100% Brebis ---
# Categoría: cheeses
# Ingredientes: sheep cheese
# Valor nutricional por 100g:
#  - Energía (kcal): 272
#  - Grasas (g): 22.8
#  - Proteínas (g): 15.7
#  - Hidratos de Carbono (g): 0.8
#  - Azúcares (g): 0.8
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Carré frais ---
# Categoría: cheeses
# Ingredientes: whole milk, cream, salt, lactic ferments,
# Valor nutricional por 100g:
#  - Energía (kcal): 193
#  - Grasas (g): 15.0
#  - Proteínas (g): 12.0
#  - Hidratos de Carbono (g): 2.5
#  - Azúcares (g): 2.5
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: St Môret ---
# Categoría: cheeses
# Ingredientes: _lait_ et _crème_ pasteurisés (Origine: France), protéines du _lait_, sel
# Valor nutricional por 100g:
#  - Energía (kcal): 205
#  - Grasas (g): 17.8
#  - Proteínas (g): 8.3
#  - Hidratos de Carbono (g): 3.0
#  - Azúcares (g): 3.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: La bûche Sainte-Maure (Poitou-Charentes ---
# Categoría: cheeses
# Ingredientes: goat's milk (origin france), salt, ferments, coagulant,
# Valor nutricional por 100g:
#  - Energía (kcal): 291
#  - Grasas (g): 23.0
#  - Proteínas (g): 20.0
#  - Hidratos de Carbono (g): 1.0
#  - Azúcares (g): 1.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: PRESIDENT CAMEMBERT 250g ---
# Categoría: cheeses
# Ingredientes: LAIT (origine France), ferments lactiques et d'affinage, sel
# Valor nutricional por 100g:
#  - Energía (kcal): 269
#  - Grasas (g): 21.0
#  - Proteínas (g): 20.0
#  - Hidratos de Carbono (g): 0.0
#  - Azúcares (g): 0.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Coulommiers Doux et Crémeux ---
# Categoría: cheeses
# Ingredientes: cow's milk, salt, ferments (contain milk),
# Valor nutricional por 100g:
#  - Energía (kcal): 283
#  - Grasas (g): 23.0
#  - Proteínas (g): 18.0
#  - Hidratos de Carbono (g): 1.0
#  - Azúcares (g): 0.1
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: President emmental coeur de meule 250g ---
# Categoría: cheeses
# Ingredientes: LAIT pasteurisé de vache , sel, ferments.
# Valor nutricional por 100g:
#  - Energía (kcal): 369
#  - Grasas (g): 29.0
#  - Proteínas (g): 27.0
#  - Hidratos de Carbono (g): 0.5
#  - Azúcares (g): 0.5
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Le Goût Primeur format familial ---
# Categoría: cheeses
# Ingredientes: Lait et crème pasteurisés (Origine : France), protéines du lait, sel,
# Valor nutricional por 100g:
#  - Energía (kcal): 205
#  - Grasas (g): 17.8
#  - Proteínas (g): 8.3
#  - Hidratos de Carbono (g): 3.0
#  - Azúcares (g): 3.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Caprice des dieux ---
# Categoría: cheeses
# Ingredientes: lait de vache pasteurisé de France, sel, ferments lactiques (lait),
# Valor nutricional por 100g:
#  - Energía (kcal): 333
#  - Grasas (g): 30.0
#  - Proteínas (g): 15.3
#  - Hidratos de Carbono (g): 0.8
#  - Azúcares (g): 0.1
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Paysan Breton - Le Fromage Fouetté Madame Loïk - Nature au Sel de Guérande ---
# Categoría: cheeses
# Ingredientes: Fromage frais, sel de Guérande 1,1%
# Valor nutricional por 100g:
#  - Energía (kcal): 252
#  - Grasas (g): 24.0
#  - Proteínas (g): 5.9
#  - Hidratos de Carbono (g): 3.0
#  - Azúcares (g): 3.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Kiri-Käse ---
# Categoría: cheeses
# Ingredientes: pasteurized fresh milk 53% (origin: france), cream 32% (origin: france), water, milk proteins, milk mineral concentrate, lactic ferments, salt,
# Valor nutricional por 100g:
#  - Energía (kcal): 305
#  - Grasas (g): 29.0
#  - Proteínas (g): 9.0
#  - Hidratos de Carbono (g): 2.0
#  - Azúcares (g): 2.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: SKYR ---
# Categoría: cheeses
# Ingredientes: Lait écrémé, ferments lactiques (lait). Lait: Origine France
# Valor nutricional por 100g:
#  - Energía (kcal): 57
#  - Grasas (g): 0.2
#  - Proteínas (g): 10.0
#  - Hidratos de Carbono (g): 3.9
#  - Azúcares (g): 3.9
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: La vache qui rit ---
# Categoría: cheeses
# Ingredientes: LAIT écrémé réhydraté (origine : France), FROMAGES, BEURRE, concentré des minéraux du LAIT, sel de fonte : polyphosphates, protéines de LAIT, concentré LACTIQUE LAITIER.
# Valor nutricional por 100g:
#  - Energía (kcal): 228
#  - Grasas (g): 17.5
#  - Proteínas (g): 11.5
#  - Hidratos de Carbono (g): 6.0
#  - Azúcares (g): 6.0
#
# Consejo de Nutrición:
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Kiri® Crème 12 portions ---
# Categoría: cheeses
# Ingredientes: LAIT frais pasteurisé 53% (origine : France), CRÈME 32% (origine : France), eau, concentré des minéraux du LAIT, protéines de LAIT, ferments LACTIQUES, sel.
# Valor nutricional por 100g:
#  - Energía (kcal): 305
#  - Grasas (g): 29.0
#  - Proteínas (g): 9.0
#  - Hidratos de Carbono (g): 2.0
#  - Azúcares (g): 2.0
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: Leerdammer original 8 tranches 200g ---
# Categoría: cheeses
# Ingredientes: LAIT pasteurisé, sel, ferments LACTIQUES, enzyme coagulante microbienne
# Valor nutricional por 100g:
#  - Energía (kcal): 352
#  - Grasas (g): 27.5
#  - Proteínas (g): 26.0
#  - Hidratos de Carbono (g): 0.1
#  - Azúcares (g): 0.1
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
#
# --- Campaña Educativa: L'original tartare ail & fines herbes ---
# Categoría: cheeses
# Ingredientes: Lait et crème pasteurisés (origine: France), ail et fines herbes (2,6%), sel, poivre. Peut contenir des fruits à coque.
# Valor nutricional por 100g:
#  - Energía (kcal): 348
#  - Grasas (g): 34.5
#  - Proteínas (g): 7.0
#  - Hidratos de Carbono (g): 2.3
#  - Azúcares (g): 2.3
#
# Consejo de Nutrición:
# Este producto tiene un contenido alto en grasas. Asegúrate de equilibrarlo con alimentos bajos en grasa.
#
# --- Fin de la Campaña Educativa ---
